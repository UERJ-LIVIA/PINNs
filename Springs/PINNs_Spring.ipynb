# %% [markdown]
# ## Problem Statement
#
# We have been given a ODE:
#
# $$
# \frac{d^2x(t)}{dt^2} = - k x(t)
# $$
#
# and boundary condition:
#
# $$
# x(0) = 5
# $$
#
#
# - Independent variables: t (input)
# - Dependent variables: x (outputs)
#
#
# We have to find out u(x,t) for all t in range [0,10]
#
# PINNs:
#
# $$
# \frac{d^2N(t)}{dt^2} = - k N(t)
# $$

# %%
import numpy as np
import plotly.graph_objects as go

import torch
import torch.nn as nn
from torch.autograd import Variable

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def build_model(input_dimension, hidden_dimension, output_dimension):
    """Build a neural network of given dimensions."""

    modules=[]
    modules.append(torch.nn.Linear(input_dimension, hidden_dimension[0]))
    modules.append(torch.nn.Tanh())
    for i in range(len(hidden_dimension)-1):
        modules.append(torch.nn.Linear(hidden_dimension[i], hidden_dimension[i+1]))
        modules.append(torch.nn.Tanh())
    
    modules.append(torch.nn.Linear(hidden_dimension[-1], output_dimension))
    
    model = torch.nn.Sequential(*modules)

    return model

# %%
net = build_model(1,[40, 40, 20, 20],1)
net = net.to(device)
mse_cost_function = torch.nn.MSELoss()
optimizer = torch.optim.Adam(net.parameters())

# %%
def get_derivative(x, t, n=1):
    
    if n == 0:
        return x
    else:
        
        dxdt = torch.autograd.grad(x, t, torch.ones(t.size()[0], 1, device=device),
        create_graph=True,
        retain_graph=True, 
        #allow_unused=True,
        )[0]
    return get_derivative(dxdt, t, n - 1)

# %%
def f(t, net, k):
    u = net(t)
    dudtdt = get_derivative(u, t, 2)
    ode = dudtdt + k*u
    return ode

# %%
k = torch.tensor([[3]], dtype=torch.float32, device=device)
init_t = torch.tensor([[0]], dtype=torch.float32, device=device)
init_x = torch.tensor([[5]], dtype=torch.float32, device=device)

n_points = 5000
t_collocation = np.linspace(0, 20, n_points).reshape(-1,1)
all_zeros = np.zeros((n_points,1))

pt_t_collocation = Variable(torch.from_numpy(t_collocation).float(), requires_grad=True).to(device)
pt_all_zeros = Variable(torch.from_numpy(all_zeros).float(), requires_grad=True).to(device)

# %%
iterations = 100000
loss_count = []


for epoch in range(iterations):
    optimizer.zero_grad() 

    init_pred = net(init_t)
    mse_b = mse_cost_function(init_pred, init_x)
    
    f_out = f(pt_t_collocation, net,k)
    mse_f = mse_cost_function(f_out, pt_all_zeros)

    loss = mse_b + mse_f
    loss_count.append(loss.item())

    loss.backward(retain_graph=True)
    optimizer.step()

    with torch.autograd.no_grad():
        if epoch % 1000 ==0:
    	    print(epoch,"Traning Loss:",loss.data)
# Out:
# 0 Traning Loss: tensor(24.5573, device='cuda:0')
# 1000 Traning Loss: tensor(1.6296, device='cuda:0')
# 2000 Traning Loss: tensor(1.4341, device='cuda:0')
# 3000 Traning Loss: tensor(1.3464, device='cuda:0')
# 4000 Traning Loss: tensor(1.3008, device='cuda:0')
# 5000 Traning Loss: tensor(1.2557, device='cuda:0')
# 6000 Traning Loss: tensor(1.1995, device='cuda:0')
# 7000 Traning Loss: tensor(1.0418, device='cuda:0')
# 8000 Traning Loss: tensor(0.9241, device='cuda:0')
# 9000 Traning Loss: tensor(0.8960, device='cuda:0')
# 10000 Traning Loss: tensor(0.8515, device='cuda:0')
# 11000 Traning Loss: tensor(0.8350, device='cuda:0')
# 67000 Traning Loss: tensor(0.0142, device='cuda:0')
# 68000 Traning Loss: tensor(0.0127, device='cuda:0')
# 69000 Traning Loss: tensor(0.0114, device='cuda:0')
# 70000 Traning Loss: tensor(0.0113, device='cuda:0')
# 71000 Traning Loss: tensor(0.0099, device='cuda:0')
# 72000 Traning Loss: tensor(0.0109, device='cuda:0')
# 73000 Traning Loss: tensor(0.1305, device='cuda:0')
# 74000 Traning Loss: tensor(0.0081, device='cuda:0')
# 75000 Traning Loss: tensor(0.0076, device='cuda:0')
# 76000 Traning Loss: tensor(0.0383, device='cuda:0')
# 77000 Traning Loss: tensor(0.0068, device='cuda:0')
# 78000 Traning Loss: tensor(0.0064, device='cuda:0')
# 79000 Traning Loss: tensor(0.0066, device='cuda:0')
# 80000 Traning Loss: tensor(0.0222, device='cuda:0')
# 81000 Traning Loss: tensor(0.0055, device='cuda:0')
# 82000 Traning Loss: tensor(0.3733, device='cuda:0')
# 83000 Traning Loss: tensor(0.0099, device='cuda:0')
# 84000 Traning Loss: tensor(0.0047, device='cuda:0')
# 85000 Traning Loss: tensor(0.0044, device='cuda:0')
# 86000 Traning Loss: tensor(0.0121, device='cuda:0')
# 87000 Traning Loss: tensor(0.0070, device='cuda:0')
# 88000 Traning Loss: tensor(0.0044, device='cuda:0')
# 89000 Traning Loss: tensor(0.0035, device='cuda:0')
# 90000 Traning Loss: tensor(0.0033, device='cuda:0')
# 91000 Traning Loss: tensor(0.0036, device='cuda:0')
# 92000 Traning Loss: tensor(0.0028, device='cuda:0')
# 93000 Traning Loss: tensor(0.0027, device='cuda:0')
# 94000 Traning Loss: tensor(0.0316, device='cuda:0')
# 95000 Traning Loss: tensor(0.0024, device='cuda:0')
# 96000 Traning Loss: tensor(0.0023, device='cuda:0')
# 97000 Traning Loss: tensor(0.0024, device='cuda:0')
# 98000 Traning Loss: tensor(0.0084, device='cuda:0')
# 99000 Traning Loss: tensor(0.0046, device='cuda:0')

# %%
f_out = net(pt_t_collocation)

# %%
xx = f_out[:, 0].data.cpu().numpy()

# %%
fig = go.Figure()
fig.add_scatter(x = t_collocation.flatten(), y=xx)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ce073287-774d-43ec-b6da-fb52a86441c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce073287-774d-43ec-b6da-fb52a86441c5")) {                    Plotly.newPlot(                        "ce073287-774d-43ec-b6da-fb52a86441c5",                        [{"x":[0.0,0.004000800160032006,0.008001600320064013,0.012002400480096018,0.016003200640128026,0.020004000800160033,0.024004800960192037,0.028005601120224044,0.03200640128025605,0.03600720144028806,0.040008001600320066,0.04400880176035207,0.048009601920384073,0.05201040208041608,0.05601120224044809,0.060012002400480095,0.0640128025605121,0.0680136027205441,0.07201440288057612,0.07601520304060812,0.08001600320064013,0.08401680336067213,0.08801760352070415,0.09201840368073615,0.09601920384076815,0.10002000400080016,0.10402080416083216,0.10802160432086418,0.11202240448089618,0.11602320464092819,0.12002400480096019,0.1240248049609922,0.1280256051210242,0.13202640528105622,0.1360272054410882,0.14002800560112022,0.14402880576115223,0.14802960592118425,0.15203040608121624,0.15603120624124825,0.16003200640128026,0.16403280656131225,0.16803360672134426,0.17203440688137628,0.1760352070414083,0.18003600720144028,0.1840368073614723,0.1880376075215043,0.1920384076815363,0.1960392078415683
360801696777344,10.157587051391602,9.954648971557617,9.750731468200684,9.545076370239258,9.338457107543945,9.132474899291992,8.92815113067627,8.725564956665039,8.524724960327148,8.32634449005127,8.13158893585205,7.941221237182617,7.75532865524292,7.573816299438477,7.396984100341797,7.225452423095703,7.059649467468262,6.899567127227783,6.745016098022461,6.595966339111328,6.4525556564331055,6.314840316772461,6.182659149169922,6.0557990074157715,5.934215545654297,5.818035125732422,5.707372665405273,5.602229118347168,5.502560138702393,5.4084014892578125,5.319852828979492,5.236934185028076,5.159516334533691,5.087368488311768,5.020240783691406,4.957836151123047,4.899725914001465,4.84536075592041,4.794167518615723,4.745617389678955,4.699193000793457,4.654360771179199,4.610640525817871,4.567686080932617,4.525264263153076,4.483208656311035,4.441436290740967,4.399997711181641,4.359031677246094,4.318698883056641,4.279190540313721,4.240749835968018,4.203600883483887,4.167901039123535,4.133777141571045,4.101312637329102,4.070486068725586,4.041216850280762,4.013390064239502,3.986818790435791,3.9612889289855957,3.936600685119629,3.912539005279541,3.8889238834381104,3.8656256198883057,3.842536211013794,3.8196029663085938,3.796814203262329,3.774174690246582,3.7517294883728027,3.7295215129852295,3.7076005935668945,3.6860156059265137,3.664793014526367,3.6439590454101562,3.623516321182251,3.6034581661224365,3.5837690830230713,3.564420700073242,3.5453929901123047,3.5266594886779785,3.5082032680511475,3.490011215209961,3.472079277038574,3.4544103145599365,3.437008857727051,3.4198861122131348,3.4030463695526123,3.3864998817443848,3.3702468872070312,3.3542890548706055,3.338621139526367,3.3232414722442627,3.308138847351074,3.293311357498169,3.2787539958953857,3.2644639015197754,3.250438690185547,3.236680030822754,3.2231874465942383,3.2099578380584717,3.196991443634033,3.184281587600708,3.1718242168426514,3.159608840942383,3.147627115249634,3.135869026184082,3.124325752258301,3.1129872798919678,3.1018471717834473,3.0908944606781006,3.080125331878662,3.0695323944091797,3.059110641479492,3.0488510131835938,3.0387496948242188,3.028799295425415,3.0189943313598633,3.009331464767456,2.9998035430908203,2.990408182144165,2.981144428253174,2.9720089435577393,2.963001012802124,2.9541192054748535,2.945363998413086,2.9367356300354004,2.9282312393188477,2.9198503494262695,2.9115936756134033,2.903460741043091,2.895447254180908,2.8875606060028076,2.879796266555786,2.872189521789551,2.8648383617401123,2.8584060668945312,2.856156587600708,2.8685407638549805,2.8963463306427,2.8561317920684814,2.8284242153167725,2.857311248779297,2.820781 ...

# %%
test_t = np.array([[0]], dtype=np.float32)
t = Variable(torch.from_numpy(test_t), requires_grad=True).to(device)

net(t)
# Out:
# tensor([[4.9976]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
result  = []
for i in range(0, 100):
  test_t = np.array([[i]], dtype=np.float32)
  t = Variable(torch.from_numpy(test_t), requires_grad=True).to(device)
  result.append(net(t).item())

# %%
t_collocation = np.linspace(0, 100, n_points).reshape(-1,1)
pt_t_collocation = Variable(torch.from_numpy(t_collocation).float(), requires_grad=True).to(device)
f_out = net(pt_t_collocation)

xx = f_out[:, 0].data.cpu().numpy()

# %% [markdown]
# #Prediction test:

# %%
fig = go.Figure()

fig.add_scatter(x = t_collocation.flatten(), y=xx)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="84de07fd-3c88-4222-bc27-89b9aabbcd80" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("